# %% [markdown]
# # **키패드 누르기**
# **https://school.programmers.co.kr/learn/courses/30/lessons/67256**

# %%
def solution(numbers, hand):
    answer = ''
    idx = 1
    r_cur = 11
    l_cur = 22
    r_dis = 0
    l_dis = 0
    if hand == "right":
        idx = -1
    for i in numbers:
        if i == 1 or i == 4 or i == 7:
            answer = answer + 'L'
            l_cur = i
        elif i == 3 or i == 6 or i == 9:
            answer = answer + 'R'
            r_cur = i
        else:
            r_dis = dist_right(r_cur, i)
            l_dis = dist_left(l_cur, i)
            if r_dis > l_dis:
                answer = answer + 'L'
                l_cur = i
            elif r_dis < l_dis:
                answer = answer + 'R'
                r_cur = i
            else:
                if idx == 1:
                    answer = answer + 'L'
                    l_cur = i
                else:
                    answer = answer + 'R'
                    r_cur = i
            
    return answer

def dist_right(r_cur, target):
    if target == 2:
        if r_cur == 11:
            return 4
        elif r_cur == 9:
            return 3
        elif r_cur == 6:
            return 2
        elif r_cur == 2:
            return 0
        elif r_cur == 5:
            return 1
        elif r_cur == 8:
            return 2
        elif r_cur == 0:
            return 3
        else:
            return 1
    elif target == 5:
        if r_cur == 11:
            return 3
        elif r_cur == 9:
            return 2
        elif r_cur == 6:
            return 1
        elif r_cur == 2:
            return 1
        elif r_cur == 5:
            return 0
        elif r_cur == 8:
            return 1
        elif r_cur == 0:
            return 2
        else:
            return 2
    elif target == 8:
        if r_cur == 11:
            return 2
        elif r_cur == 9:
            return 1
        elif r_cur == 6:
            return 2
        elif r_cur == 2:
            return 2
        elif r_cur == 5:
            return 1
        elif r_cur == 8:
            return 0
        elif r_cur == 0:
            return 1
        else:
            return 3
    elif target == 0:
        if r_cur == 11:
            return 1
        elif r_cur == 9:
            return 2
        elif r_cur == 6:
            return 3
        elif r_cur == 2:
            return 3
        elif r_cur == 5:
            return 2
        elif r_cur == 8:
            return 1
        elif r_cur == 0:
            return 0
        else:
            return 4
    else:
        return None
    
def dist_left(l_cur, target):
    if target == 2:
        if l_cur == 22:
            return 4
        elif l_cur == 7:
            return 3
        elif l_cur == 4:
            return 2
        elif l_cur == 2:
            return 0
        elif l_cur == 5:
            return 1
        elif l_cur == 8:
            return 2
        elif l_cur == 0:
            return 3
        else:
            return 1
    elif target == 5:
        if l_cur == 22:
            return 3
        elif l_cur == 7:
            return 2
        elif l_cur == 4:
            return 1
        elif l_cur == 2:
            return 1
        elif l_cur == 5:
            return 0
        elif l_cur == 8:
            return 1
        elif l_cur == 0:
            return 2
        else:
            return 2
    elif target == 8:
        if l_cur == 22:
            return 2
        elif l_cur == 7:
            return 1
        elif l_cur == 4:
            return 2
        elif l_cur == 2:
            return 2
        elif l_cur == 5:
            return 1
        elif l_cur == 8:
            return 0
        elif l_cur == 0:
            return 1
        else:
            return 3
    elif target == 0:
        if l_cur == 22:
            return 1
        elif l_cur == 7:
            return 2
        elif l_cur == 4:
            return 3
        elif l_cur == 2:
            return 3
        elif l_cur == 5:
            return 2
        elif l_cur == 8:
            return 1
        elif l_cur == 0:
            return 0
        else:
            return 4
    else:
        return None
